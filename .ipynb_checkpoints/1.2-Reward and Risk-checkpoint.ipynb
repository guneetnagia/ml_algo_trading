# %%
## Measure Rewawrd and risk of investment
# Visualize the data
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8-whitegrid")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates= ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2014-10-01  38.8802      NaN
# 2014-10-02  38.7616  -0.0031
# 2014-10-03  39.0411   0.0072
# 2014-10-06  39.0411   0.0000
# 2014-10-07  38.5667  -0.0122
# ...             ...      ...
# 2026-02-03 411.2100  -0.0287
# 2026-02-04 414.1900   0.0072
# 2026-02-05 393.6700  -0.0495
# 2026-02-06 401.1400   0.0190
# 2026-02-09 413.6000   0.0311
#
# [2856 rows x 2 columns]

# %%
msft.Price.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
# Reward = Positive Returns
# Risk = Volatility of returns

# %%
msft.describe()
# Out:
#           Price   Returns
# count 2856.0000 2855.0000
# mean   204.6902    0.0010
# std    145.1291    0.0170
# min     34.4371   -0.1474
# 25%     66.3181   -0.0069
# 50%    178.0707    0.0009
# 75%    313.3869    0.0094
# max    541.0574    0.1422

# %%
# Arithmetic mean return => Reward
mu = msft.Returns.mean()
mu
# Out:
# np.float64(0.0009728085631275455)
