# %%
# Visualize the data
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8-whitegrid")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates= ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT  RELIANCE.NS  \
# Date
# 2014-10-01 108.4067   383.6150    1.2628 1214.6000  38.8802     198.4096
# 2014-10-02 107.9719   375.0720    1.2624 1214.2000  38.7616          NaN
# 2014-10-03 109.8762   359.5120    1.2671 1192.2000  39.0411          NaN
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN          NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN          NaN
# ...             ...        ...       ...       ...      ...          ...
# 2026-02-05 236.9500 62702.0977    1.1802 4861.3999 393.6700    1443.4000
# 2026-02-06 243.0300 70555.3906    1.1778 4951.2002 401.1400    1450.8000
# 2026-02-07      NaN 69281.9688       NaN       NaN      NaN          NaN
# 2026-02-08      NaN 70264.7266       NaN       NaN      NaN          NaN
# 2026-02-09 244.7100 70120.7812    1.1826 5050.8999 413.6000    1461.6000
#
#                  ^DJI
# Date
# 2014-10-01 16804.7109
# 2014-10-02 16801.0508
# ...

# %%
bit = close["BTC-USD"].dropna().to_frame().copy()
bit
# Out:
#               BTC-USD
# Date
# 2014-10-01   383.6150
# 2014-10-02   375.0720
# 2014-10-03   359.5120
# 2014-10-04   328.8660
# 2014-10-05   320.5100
# ...               ...
# 2026-02-05 62702.0977
# 2026-02-06 70555.3906
# 2026-02-07 69281.9688
# 2026-02-08 70264.7266
# 2026-02-09 70120.7812
#
# [4150 rows x 1 columns]

# %%
bit.rename(columns={"BTC-USD":"Price"}, inplace=True)

# %%
bit["P_diff"] = bit.Price.diff(periods=1)
bit
# Out:
#                 Price      P_diff
# Date
# 2014-10-01   383.6150         NaN
# 2014-10-02   375.0720     -8.5430
# 2014-10-03   359.5120    -15.5600
# 2014-10-04   328.8660    -30.6460
# 2014-10-05   320.5100     -8.3560
# ...               ...         ...
# 2026-02-05 62702.0977 -10317.6055
# 2026-02-06 70555.3906   7853.2930
# 2026-02-07 69281.9688  -1273.4219
# 2026-02-08 70264.7266    982.7578
# 2026-02-09 70120.7812   -143.9453
#
# [4150 rows x 2 columns]

# %%
bit["Returns"] = bit.Price.pct_change(periods=1)
bitmsft.Price.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)
plt.show()
# Out:
#                 Price      P_diff  Returns
# Date
# 2014-10-01   383.6150         NaN      NaN
# 2014-10-02   375.0720     -8.5430  -0.0223
# 2014-10-03   359.5120    -15.5600  -0.0415
# 2014-10-04   328.8660    -30.6460  -0.0852
# 2014-10-05   320.5100     -8.3560  -0.0254
# ...               ...         ...      ...
# 2026-02-05 62702.0977 -10317.6055  -0.1413
# 2026-02-06 70555.3906   7853.2930   0.1252
# 2026-02-07 69281.9688  -1273.4219  -0.0180
# 2026-02-08 70264.7266    982.7578   0.0142
# 2026-02-09 70120.7812   -143.9453  -0.0020
#
# [4150 rows x 3 columns]

# %%
bit.Price.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
bit.drop(columns=["P_diff"], inplace = True)

# %%
bit.to_csv("bit.csv")

# %%
bit = pd.read_csv("bit.csv", index_col = "Date", parse_dates= ["Date"])
bit
# Out:
#                 Price  Returns
# Date
# 2014-10-01   383.6150      NaN
# 2014-10-02   375.0720  -0.0223
# 2014-10-03   359.5120  -0.0415
# 2014-10-04   328.8660  -0.0852
# 2014-10-05   320.5100  -0.0254
# ...               ...      ...
# 2026-02-05 62702.0977  -0.1413
# 2026-02-06 70555.3906   0.1252
# 2026-02-07 69281.9688  -0.0180
# 2026-02-08 70264.7266   0.0142
# 2026-02-09 70120.7812  -0.0020
#
# [4150 rows x 2 columns]

# %%
# Arithmetic mean return => Reward
bu = bit.Returns.mean()
bu
# Out:
# np.float64(0.0018793207994871716)

# %%
# Standard variation of Return => Risk/volatility
sigma = bit.Returns.std()
sigma
# Out:
# 0.03517295318779696
