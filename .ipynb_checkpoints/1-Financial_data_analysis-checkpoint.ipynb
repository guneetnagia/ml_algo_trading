# %%
import pandas as py
import yfinance as yf

# %%
start="2014-10-01"
end="2026-02-10"

# %%
symbol= ["BA", "MSFT", "^DJI", "EURUSD=X", "GC=F", "BTC-USD", "Reliance.NS"]

# %%
yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  7 of 7 completed
# Price         Close                                                     \
# Ticker           BA    BTC-USD EURUSD=X      GC=F     MSFT RELIANCE.NS
# Date
# 2014-10-01 108.4067   383.6150   1.2628 1214.6000  38.8802    198.4096
# 2014-10-02 107.9719   375.0720   1.2624 1214.2000  38.7616         NaN
# 2014-10-03 109.8762   359.5120   1.2671 1192.2000  39.0411         NaN
# 2014-10-04      NaN   328.8660      NaN       NaN      NaN         NaN
# 2014-10-05      NaN   320.5100      NaN       NaN      NaN         NaN
# ...             ...        ...      ...       ...      ...         ...
# 2026-02-05 236.9500 62702.0977   1.1802 4861.3999 393.6700   1443.4000
# 2026-02-06 243.0300 70555.3906   1.1778 4951.2002 401.1400   1450.8000
# 2026-02-07      NaN 69281.9688      NaN       NaN      NaN         NaN
# 2026-02-08      NaN 70264.7266      NaN       NaN      NaN         NaN
# 2026-02-09 244.7100 70120.7812   1.1826 5050.8999 413.6000   1461.6000
#
# Price                     High                      ...     Open              \
# Ticker           ^DJI       BA    BTC-USD EURUSD=X  ...     MSFT RELIANCE.NS
# Date                                                ...
# 2014-10-01 16804.7109 110.7544   391.3790   1.2640  ...  39.1936    201.9190
# 2014-10-02 16801.0508 109.1719   385.4970   1.2691  ...  38.8209         NaN
# 2014-10-03 17009.6895 110.3197   377.6950   1.2670  ...  38.9479         NaN
# 2014-10-04        NaN      NaN   364.4870      NaN  ...      NaN         NaN
# 2014-10-05        NaN      NaN   341.8010      NaN  ...      NaN         NaN
# ...               ...      ...        ...      ...  ...      ...         ...
# 2026-02-05 48908.7188 240.3300 73161.5547   1.1820  ... 407.4400   1457.0000
# 2026-02-06 50115.6719 246.3000 71681.3047   1.1826  ... 399.1700   1441.5000
# 2026-02-07        NaN      NaN 71611.1484      NaN  ...      NaN         NaN
# 2026-02-08        NaN      NaN 72206.9062      NaN  ...      NaN         NaN
# 2026-02-09 50135.8711 245.8400 71369.9688   1.1925  ... 404.8500   1458.0000
#
# Price                       Volume                                   \
# Ticker           ^DJI           BA       BTC-USD EURUSD=X      GC=F
# Date
# 2014-10-01 17040.4609 5265200.0000      26229400   0.0000  178.0000
# 2014-10-02 16808.2695 3204500.0000      21777700   0.0000  176.0000
# 2014-10-03 16802.1992 3075900.0000      30901200   0.0000  499.0000
# 2014-10-04        NaN          NaN      47236500      NaN       NaN
# 2014-10-05        NaN          NaN      83308096      NaN       NaN
# ...               ...          ...           ...      ...       ...
# 2026-02-05 49313.0391 7377300.0000  125509410908   0.0000  793.0000
# 2026-02-06 49032.1914 6701200.0000  114674259489   0.0000 1386.0000
# 2026-02-07        NaN          NaN   62347107663      NaN       NaN
# 2026-02-08        NaN          NaN   39721722619      NaN       NaN
# 2026-02-09 50047.7891 4707200.0000   52081598792   0.0000  170.0000
#
# Price
# Ticker              MSFT   RELIANCE.NS           ^DJI
# Date
# 2014-10-01 38088400.0000  8656245.0000 104240000.0000
# 2014-10-02 25119400.0000           NaN  75490000.0000
# 2014-10-03 32453200.0000           NaN  87940000.0000
# 2014-10-04           NaN           NaN            NaN
# 2014-10-05           NaN           NaN            NaN
# ...                  ...           ...            ...
# 2026-02-05 66289200.0000 11763658.0000 710270000.0000
# 2026-02-06 53515300.0000  8277304.0000 775490000.0000
# 2026-02-07           NaN           NaN            NaN
# 2026-02-08           NaN           NaN            NaN
# 2026-02-09 45480500.0000  5775864.0000 623640000.0000
#
# [4150 rows x 35 columns]

# %%
df = yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
print(df)
# Out:
# Price         Close                                                     \
# Ticker           BA    BTC-USD EURUSD=X      GC=F     MSFT RELIANCE.NS
# Date
# 2014-10-01 108.4067   383.6150   1.2628 1214.6000  38.8802    198.4096
# 2014-10-02 107.9719   375.0720   1.2624 1214.2000  38.7616         NaN
# 2014-10-03 109.8762   359.5120   1.2671 1192.2000  39.0411         NaN
# 2014-10-04      NaN   328.8660      NaN       NaN      NaN         NaN
# 2014-10-05      NaN   320.5100      NaN       NaN      NaN         NaN
# ...             ...        ...      ...       ...      ...         ...
# 2026-02-05 236.9500 62702.0977   1.1802 4861.3999 393.6700   1443.4000
# 2026-02-06 243.0300 70555.3906   1.1778 4951.2002 401.1400   1450.8000
# 2026-02-07      NaN 69281.9688      NaN       NaN      NaN         NaN
# 2026-02-08      NaN 70264.7266      NaN       NaN      NaN         NaN
# 2026-02-09 244.7100 70120.7812   1.1826 5050.8999 413.6000   1461.6000
#
# Price                     High                      ...     Open              \
# Ticker           ^DJI       BA    BTC-USD EURUSD=X  ...     MSFT RELIANCE.NS
# Date                                                ...
# 2014-10-01 16804.7109 110.7544   391.3790   1.2640  ...  39.1936    201.9190
# 2014-10-02 16801.0508 109.1719   385.4970   1.2691  ...  38.8209         NaN
# 2014-10-03 17009.6895 110.3197   377.6950   1.2670  ...  38.9479         NaN
# 2014-10-04        NaN      NaN   364.4870      NaN  ...      NaN         NaN
# 2014-10-05        NaN      NaN   341.8010      NaN  ...      NaN         NaN
# ...               ...      ...        ...      ...  ...      ...         ...
# 2026-02-05 48908.7188 240.3300 73161.5547   1.1820  ... 407.4400   1457.0000
# 2026-02-06 50115.6719 246.3000 71681.3047   1.1826  ... 399.1700   1441.5000
# 2026-02-07        NaN      NaN 71611.1484      NaN  ...      NaN         NaN
# 2026-02-08        NaN      NaN 72206.9062      NaN  ...      NaN         NaN
# 2026-02-09 50135.8711 245.8400 71369.9688   1.1925  ... 404.8500   1458.0000
#
# Price                       Volume                                   \
# Ticker           ^DJI           BA       BTC-USD EURUSD=X      GC=F
# Date
# 2014-10-01 17040.4609 5265200.0000      26229400   0.0000  178.0000
# 2014-10-02 16808.2695 3204500.0000      21777700   0.0000  176.0000
# 2014-10-03 16802.1992 3075900.0000      30901200   0.0000  499.0000
# 2014-10-04        NaN          NaN      47236500      NaN       NaN
# 2014-10-05        NaN          NaN      83308096      NaN       NaN
# ...               ...          ...           ...      ...       ...
# 2026-02-05 49313.0391 7377300.0000  125509410908   0.0000  793.0000
# 2026-02-06 49032.1914 6701200.0000  114674259489   0.0000 1386.0000
# 2026-02-07        NaN          NaN   62347107663      NaN       NaN
# 2026-02-08        NaN          NaN   39721722619      NaN       NaN
# 2026-02-09 50047.7891 4707200.0000   52081598792   0.0000  170.0000
#
# Price
# Ticker              MSFT   RELIANCE.NS           ^DJI
# Date
# 2014-10-01 38088400.0000  8656245.0000 104240000.0000
# 2014-10-02 25119400.0000           NaN  75490000.0000
# 2014-10-03 32453200.0000           NaN  87940000.0000
# 2014-10-04           NaN           NaN            NaN
# 2014-10-05           NaN           NaN            NaN
# ...                  ...           ...            ...
# 2026-02-05 66289200.0000 11763658.0000 710270000.0000
# 2026-02-06 53515300.0000  8277304.0000 775490000.0000
# 2026-02-07           NaN           NaN            NaN
# 2026-02-08           NaN           NaN            NaN
# 2026-02-09 45480500.0000  5775864.0000 623640000.0000
#
# [4150 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4150 entries, 2014-10-01 to 2026-02-09
# Freq: D
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Close, BA)            2856 non-null   float64
#  1   (Close, BTC-USD)       4150 non-null   float64
#  2   (Close, EURUSD=X)      2956 non-null   float64
#  3   (Close, GC=F)          2855 non-null   float64
#  4   (Close, MSFT)          2856 non-null   float64
#  5   (Close, RELIANCE.NS)   2801 non-null   float64
#  6   (Close, ^DJI)          2856 non-null   float64
#  7   (High, BA)             2856 non-null   float64
#  8   (High, BTC-USD)        4150 non-null   float64
#  9   (High, EURUSD=X)       2956 non-null   float64
#  10  (High, GC=F)           2855 non-null   float64
#  11  (High, MSFT)           2856 non-null   float64
#  12  (High, RELIANCE.NS)    2801 non-null   float64
#  13  (High, ^DJI)           2856 non-null   float64
#  14  (Low, BA)              2856 non-null   float64
#  15  (Low, BTC-USD)         4150 non-null   float64
#  16  (Low, EURUSD=X)        2956 non-null   float64
#  17  (Low, GC=F)            2855 non-null   float64
#  18  (Low, MSFT)            2856 non-null   float64
#  19  (Low, RELIANCE.NS)     2801 non-null   float64
#  20  (Low, ^DJI)            2856 non-null   float64
#  21  (Open, BA)             2856 non-null   float64
#  22  (Open, BTC-USD)        4150 non-null   float64
#  23  (Open, EURUSD=X)       2956 non-null   float64
#  24  (Open, GC=F)           2855 non-null   float64
#  25  (Open, MSFT)           2856 non-null   float64
#  26  (Open, RELIANCE.NS)    2801 non-null   float64
#  27  (Open, ^DJI)           2856 non-null   float64
#  28  (Volume, BA)           2856 non-null   float64
#  29  (Volume, BTC-USD)      4150 non-null   int64
#  30  (Volume, EURUSD=X)     2956 non-null   float64
#  31  (Volume, GC=F)         2855 non-null   float64
#  32  (Volume, MSFT)         2856 non-null   float64
#  33  (Volume, RELIANCE.NS)  2801 non-null   float64
#  34  (Volume, ^DJI)         2856 non-null   float64
# dtypes: float64(34), int64(1)
# memory usage: 1.1 MB

# %%
df.to_csv("multi_assets.csv")

# %%
# Visualize the data
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8-whitegrid")

# %%
df = pd.read_csv("multi_assets.csv", header = [0,1], index_col=0, parse_dates=[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4150 entries, 2014-10-01 to 2026-02-09
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Close, BA)            2856 non-null   float64
#  1   (Close, BTC-USD)       4150 non-null   float64
#  2   (Close, EURUSD=X)      2956 non-null   float64
#  3   (Close, GC=F)          2855 non-null   float64
#  4   (Close, MSFT)          2856 non-null   float64
#  5   (Close, RELIANCE.NS)   2801 non-null   float64
#  6   (Close, ^DJI)          2856 non-null   float64
#  7   (High, BA)             2856 non-null   float64
#  8   (High, BTC-USD)        4150 non-null   float64
#  9   (High, EURUSD=X)       2956 non-null   float64
#  10  (High, GC=F)           2855 non-null   float64
#  11  (High, MSFT)           2856 non-null   float64
#  12  (High, RELIANCE.NS)    2801 non-null   float64
#  13  (High, ^DJI)           2856 non-null   float64
#  14  (Low, BA)              2856 non-null   float64
#  15  (Low, BTC-USD)         4150 non-null   float64
#  16  (Low, EURUSD=X)        2956 non-null   float64
#  17  (Low, GC=F)            2855 non-null   float64
#  18  (Low, MSFT)            2856 non-null   float64
#  19  (Low, RELIANCE.NS)     2801 non-null   float64
#  20  (Low, ^DJI)            2856 non-null   float64
#  21  (Open, BA)             2856 non-null   float64
#  22  (Open, BTC-USD)        4150 non-null   float64
#  23  (Open, EURUSD=X)       2956 non-null   float64
#  24  (Open, GC=F)           2855 non-null   float64
#  25  (Open, MSFT)           2856 non-null   float64
#  26  (Open, RELIANCE.NS)    2801 non-null   float64
#  27  (Open, ^DJI)           2856 non-null   float64
#  28  (Volume, BA)           2856 non-null   float64
#  29  (Volume, BTC-USD)      4150 non-null   int64
#  30  (Volume, EURUSD=X)     2956 non-null   float64
#  31  (Volume, GC=F)         2855 non-null   float64
#  32  (Volume, MSFT)         2856 non-null   float64
#  33  (Volume, RELIANCE.NS)  2801 non-null   float64
#  34  (Volume, ^DJI)         2856 non-null   float64
# dtypes: float64(34), int64(1)
# memory usage: 1.1 MB

# %%
df.Volume # outer index level
# Out:
# Ticker               BA       BTC-USD  EURUSD=X      GC=F          MSFT  \
# Date
# 2014-10-01 5265200.0000      26229400    0.0000  178.0000 38088400.0000
# 2014-10-02 3204500.0000      21777700    0.0000  176.0000 25119400.0000
# 2014-10-03 3075900.0000      30901200    0.0000  499.0000 32453200.0000
# 2014-10-04          NaN      47236500       NaN       NaN           NaN
# 2014-10-05          NaN      83308096       NaN       NaN           NaN
# ...                 ...           ...       ...       ...           ...
# 2026-02-05 7377300.0000  125509410908    0.0000  793.0000 66289200.0000
# 2026-02-06 6701200.0000  114674259489    0.0000 1386.0000 53515300.0000
# 2026-02-07          NaN   62347107663       NaN       NaN           NaN
# 2026-02-08          NaN   39721722619       NaN       NaN           NaN
# 2026-02-09 4707200.0000   52081598792    0.0000  170.0000 45480500.0000
#
# Ticker       RELIANCE.NS           ^DJI
# Date
# 2014-10-01  8656245.0000 104240000.0000
# 2014-10-02           NaN  75490000.0000
# 2014-10-03           NaN  87940000.0000
# 2014-10-04           NaN            NaN
# 2014-10-05           NaN            NaN
# ...                  ...            ...
# 2026-02-05 11763658.0000 710270000.0000
# 2026-02-06  8277304.0000 775490000.0000
# 2026-02-07           NaN            NaN
# 2026-02-08           NaN            NaN
# 2026-02-09  5775864.0000 623640000.0000
#
# [4150 rows x 7 columns]

# %%
df.Volume.BA # one columne
# Out:
# Date
# 2014-10-01   5265200.0000
# 2014-10-02   3204500.0000
# 2014-10-03   3075900.0000
# 2014-10-04            NaN
# 2014-10-05            NaN
#                  ...
# 2026-02-05   7377300.0000
# 2026-02-06   6701200.0000
# 2026-02-07            NaN
# 2026-02-08            NaN
# 2026-02-09   4707200.0000
# Name: BA, Length: 4150, dtype: float64

# %%
df.loc[:, ("Volume", "BA")] #one column
# Out:
# Date
# 2014-10-01   5265200.0000
# 2014-10-02   3204500.0000
# 2014-10-03   3075900.0000
# 2014-10-04            NaN
# 2014-10-05            NaN
#                  ...
# 2026-02-05   7377300.0000
# 2026-02-06   6701200.0000
# 2026-02-07            NaN
# 2026-02-08            NaN
# 2026-02-09   4707200.0000
# Name: (Volume, BA), Length: 4150, dtype: float64

# %%
df.loc["2015-01-07"] # one day/row
# Out:
# Price   Ticker
# Close   BA                 113.2724
#         BTC-USD            294.3370
#         EURUSD=X             1.1875
#         GC=F              1210.6000
#         MSFT                39.4067
#         RELIANCE.NS        182.8098
#         ^DJI             17584.5195
# High    BA                 113.6747
#         BTC-USD            298.7540
#         EURUSD=X             1.1900
#         GC=F              1219.2000
#         MSFT                39.6027
#         RELIANCE.NS        183.7728
#         ^DJI             17597.0801
# Low     BA                 112.5814
#         BTC-USD            283.0790
#         EURUSD=X             1.1804
#         GC=F              1210.6000
#         MSFT                38.7759
#         RELIANCE.NS        179.1078
#         ^DJI             17374.7793
# Open    BA                 112.5989
#         BTC-USD            286.0770
#         EURUSD=X             1.1875
#         GC=F              1219.2000
#         MSFT                39.1936
#         RELIANCE.NS        179.1292
#         ^DJI             17374.7793
# Volume  BA             3573200.0000
#         BTC-USD       24866800.0000
#         EURUSD=X             0.0000
#         GC=F                29.0000
#         MSFT          29114100.0000
#         RELIANCE.NS   20720312.0000
#         ^DJI          91030000.0000
# Name: 2015-01-07 00:00:00, dtype: float64

# %%
df.loc["2015"] # one year
# Out:
# Price         Close                                                  \
# Ticker           BA  BTC-USD EURUSD=X      GC=F    MSFT RELIANCE.NS
# Date
# 2015-01-01      NaN 314.2490   1.2099       NaN     NaN    189.9998
# 2015-01-02 113.6572 315.0320   1.2089 1186.0000 39.8585    189.4969
# 2015-01-03      NaN 281.0820      NaN       NaN     NaN         NaN
# 2015-01-04      NaN 264.1950      NaN       NaN     NaN         NaN
# 2015-01-05 112.8701 274.4740   1.1946 1203.9000 39.4919    187.4213
# ...             ...      ...      ...       ...     ...         ...
# 2015-12-27      NaN 422.8230      NaN       NaN     NaN         NaN
# 2015-12-28 129.6283 422.2790   1.0966 1070.5000 48.9904    218.9374
# 2015-12-29 132.1484 432.9830   1.0975 1077.5000 49.5158    220.0209
# 2015-12-30 131.3055 426.6200   1.0928 1060.1000 49.3056    217.6590
# 2015-12-31 129.6732 430.5670   1.0934 1060.3000 48.5789    219.8475
#
# Price                     High                    ...    Open              \
# Ticker           ^DJI       BA  BTC-USD EURUSD=X  ...    MSFT RELIANCE.NS
# Date                                              ...
# 2015-01-01        NaN      NaN 320.4350   1.2099  ...     NaN    189.6574
# 2015-01-02 17832.9902 115.3103 315.8390   1.2090  ... 39.7732    190.0426
# 2015-01-03        NaN      NaN 315.1500      NaN  ...     NaN         NaN
# 2015-01-04        NaN      NaN 287.2300      NaN  ...     NaN         NaN
# 2015-01-05 17501.6504 113.6310 278.3410   1.1976  ... 39.5260    189.3793
# ...               ...      ...      ...      ...  ...     ...         ...
# 2015-12-27        NaN      NaN 424.0070      NaN  ...     NaN         NaN
# 2015-12-28 17528.2695 129.7449 429.7690   1.1000  ... 48.4650    216.8139
# 2015-12-29 17720.9805 132.3367 432.9830   1.1000  ... 49.2881    218.9375
# 2015-12-30 17603.8691 132.7314 434.3870   1.0950  ... 49.4457    219.9342
# 2015-12-31 17425.0293 130.9018 432.9210   1.0939  ... 49.0692    217.4207
#
# Price                       Volume                                            \
# Ticker           ^DJI           BA   BTC-USD EURUSD=X     GC=F          MSFT
# Date
# 2015-01-01        NaN          NaN   8036550   0.0000      NaN           NaN
# 2015-01-02 17823.0703 4294200.0000   7860650   0.0000 138.0000 27913900.0000
# 2015-01-03        NaN          NaN  33054400      NaN      NaN           NaN
# 2015-01-04        NaN          NaN  55629100      NaN      NaN           NaN
# 2015-01-05 17821.3008 5024800.0000  43962800   0.0000 470.0000 39673900.0000
# ...               ...          ...       ...      ...      ...           ...
# 2015-12-27        NaN          NaN  53591200      NaN      NaN           NaN
# 2015-12-28 17535.6602 1980000.0000  49638600   0.0000 361.0000 22458300.0000
# 2015-12-29 17547.3691 3133600.0000  51596500   0.0000 252.0000 27731400.0000
# 2015-12-30 17711.9395 1619000.0000  46889400   0.0000  71.0000 21704500.0000
# 2015-12-31 17590.6602 2105200.0000  45996600   0.0000  10.0000 27334100.0000
#
# Price
# Ticker       RELIANCE.NS           ^DJI
# Date
# 2015-01-01  2963643.0000            NaN
# 2015-01-02  7331366.0000  76270000.0000
# 2015-01-03           NaN            NaN
# 2015-01-04           NaN            NaN
# 2015-01-05 10103941.0000 116160000.0000
# ...                  ...            ...
# 2015-12-27           NaN            NaN
# 2015-12-28 12885935.0000  59770000.0000
# 2015-12-29 14913870.0000  69860000.0000
# 2015-12-30  8151610.0000  59760000.0000
# 2015-12-31 18483713.0000  93690000.0000
#
# [365 rows x 35 columns]

# %%
df.loc["2020-06":, ("Volume", "BA")] # one month for one column
# Out:
# Date
# 2020-06-01   27127300.0000
# 2020-06-02   24780500.0000
# 2020-06-03   66486400.0000
# 2020-06-04   67155600.0000
# 2020-06-05   99846000.0000
#                   ...
# 2026-02-05    7377300.0000
# 2026-02-06    6701200.0000
# 2026-02-07             NaN
# 2026-02-08             NaN
# 2026-02-09    4707200.0000
# Name: (Volume, BA), Length: 2080, dtype: float64

# %%
df = df.swaplevel(axis = "columns").sort_index(axis="columns") #swap outer and inner index
df
# Out:
# Price         Close                                                     \
# Ticker           BA    BTC-USD EURUSD=X      GC=F     MSFT RELIANCE.NS
# Date
# 2014-10-01 108.4067   383.6150   1.2628 1214.6000  38.8802    198.4096
# 2014-10-02 107.9719   375.0720   1.2624 1214.2000  38.7616         NaN
# 2014-10-03 109.8762   359.5120   1.2671 1192.2000  39.0411         NaN
# 2014-10-04      NaN   328.8660      NaN       NaN      NaN         NaN
# 2014-10-05      NaN   320.5100      NaN       NaN      NaN         NaN
# ...             ...        ...      ...       ...      ...         ...
# 2026-02-05 236.9500 62702.0977   1.1802 4861.3999 393.6700   1443.4000
# 2026-02-06 243.0300 70555.3906   1.1778 4951.2002 401.1400   1450.8000
# 2026-02-07      NaN 69281.9688      NaN       NaN      NaN         NaN
# 2026-02-08      NaN 70264.7266      NaN       NaN      NaN         NaN
# 2026-02-09 244.7100 70120.7812   1.1826 5050.8999 413.6000   1461.6000
#
# Price                     High                      ...     Open              \
# Ticker           ^DJI       BA    BTC-USD EURUSD=X  ...     MSFT RELIANCE.NS
# Date                                                ...
# 2014-10-01 16804.7109 110.7544   391.3790   1.2640  ...  39.1936    201.9190
# 2014-10-02 16801.0508 109.1719   385.4970   1.2691  ...  38.8209         NaN
# 2014-10-03 17009.6895 110.3197   377.6950   1.2670  ...  38.9479         NaN
# 2014-10-04        NaN      NaN   364.4870      NaN  ...      NaN         NaN
# 2014-10-05        NaN      NaN   341.8010      NaN  ...      NaN         NaN
# ...               ...      ...        ...      ...  ...      ...         ...
# 2026-02-05 48908.7188 240.3300 73161.5547   1.1820  ... 407.4400   1457.0000
# 2026-02-06 50115.6719 246.3000 71681.3047   1.1826  ... 399.1700   1441.5000
# 2026-02-07        NaN      NaN 71611.1484      NaN  ...      NaN         NaN
# 2026-02-08        NaN      NaN 72206.9062      NaN  ...      NaN         NaN
# 2026-02-09 50135.8711 245.8400 71369.9688   1.1925  ... 404.8500   1458.0000
#
# Price                       Volume                                   \
# Ticker           ^DJI           BA       BTC-USD EURUSD=X      GC=F
# Date
# 2014-10-01 17040.4609 5265200.0000      26229400   0.0000  178.0000
# 2014-10-02 16808.2695 3204500.0000      21777700   0.0000  176.0000
# 2014-10-03 16802.1992 3075900.0000      30901200   0.0000  499.0000
# 2014-10-04        NaN          NaN      47236500      NaN       NaN
# 2014-10-05        NaN          NaN      83308096      NaN       NaN
# ...               ...          ...           ...      ...       ...
# 2026-02-05 49313.0391 7377300.0000  125509410908   0.0000  793.0000
# 2026-02-06 49032.1914 6701200.0000  114674259489   0.0000 1386.0000
# 2026-02-07        NaN          NaN   62347107663      NaN       NaN
# 2026-02-08        NaN          NaN   39721722619      NaN       NaN
# 2026-02-09 50047.7891 4707200.0000   52081598792   0.0000  170.0000
#
# Price
# Ticker              MSFT   RELIANCE.NS           ^DJI
# Date
# 2014-10-01 38088400.0000  8656245.0000 104240000.0000
# 2014-10-02 25119400.0000           NaN  75490000.0000
# 2014-10-03 32453200.0000           NaN  87940000.0000
# 2014-10-04           NaN           NaN            NaN
# 2014-10-05           NaN           NaN            NaN
# ...                  ...           ...            ...
# 2026-02-05 66289200.0000 11763658.0000 710270000.0000
# 2026-02-06 53515300.0000  8277304.0000 775490000.0000
# 2026-02-07           NaN           NaN            NaN
# 2026-02-08           NaN           NaN            NaN
# 2026-02-09 45480500.0000  5775864.0000 623640000.0000
#
# [4150 rows x 35 columns]

# %%
close = df.Close.copy() # select daily close price only
close
# Out:
# Ticker           BA    BTC-USD  EURUSD=X      GC=F     MSFT  RELIANCE.NS  \
# Date
# 2014-10-01 108.4067   383.6150    1.2628 1214.6000  38.8802     198.4096
# 2014-10-02 107.9719   375.0720    1.2624 1214.2000  38.7616          NaN
# 2014-10-03 109.8762   359.5120    1.2671 1192.2000  39.0411          NaN
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN          NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN          NaN
# ...             ...        ...       ...       ...      ...          ...
# 2026-02-05 236.9500 62702.0977    1.1802 4861.3999 393.6700    1443.4000
# 2026-02-06 243.0300 70555.3906    1.1778 4951.2002 401.1400    1450.8000
# 2026-02-07      NaN 69281.9688       NaN       NaN      NaN          NaN
# 2026-02-08      NaN 70264.7266       NaN       NaN      NaN          NaN
# 2026-02-09 244.7100 70120.7812    1.1826 5050.8999 413.6000    1461.6000
#
# Ticker           ^DJI
# Date
# 2014-10-01 16804.7109
# 2014-10-02 16801.0508
# 2014-10-03 17009.6895
# 2014-10-04        NaN
# 2014-10-05        NaN
# ...               ...
# 2026-02-05 48908.7188
# 2026-02-06 50115.6719
# 2026-02-07        NaN
# 2026-02-08        NaN
# 2026-02-09 50135.8711
#
# [4150 rows x 7 columns]

# %%
close.describe()
# Out:
# Ticker        BA     BTC-USD  EURUSD=X      GC=F      MSFT  RELIANCE.NS  \
# count  2856.0000   4150.0000 2956.0000 2855.0000 2856.0000    2801.0000
# mean    208.7822  27510.4727    1.1235 1785.9736  204.6902     784.6751
# std      76.7452  32054.2271    0.0550  720.2865  145.1291     449.5385
# min      95.0100    178.1030    0.9596 1050.8000   34.4371     173.4906
# 25%     147.3250   2950.3100    1.0857 1266.2000   66.3181     349.4203
# 50%     195.4100  11000.9878    1.1193 1692.9000  178.0707     747.7937
# 75%     238.3125  42941.8076    1.1648 1938.9000  313.3869    1179.8917
# max     430.3000 124752.5312    1.2822 5318.3999  541.0574    1592.3000
#
# Ticker       ^DJI
# count   2856.0000
# mean   29112.3640
# std     8732.7721
# min    15660.1797
# 25%    21569.3203
# 50%    27692.1855
# 75%    34787.9316
# max    50135.8711

# %%
close.BA.dropna().plot(figsize = (15,8), fontsize = 13)
plt.legend(fontsize=13)
plt.show()

# %%
close.dropna().plot(figsize = (15,8), fontsize = 13)
plt.legend(fontsize=13)
plt.show()

# %%
# it is hard to compare 
# Normalize timeseries to Base Value (100)
close.iloc[0,0] # first price of Boing (BA)
# Out:
# np.float64(108.40666198730467)

# %%
close.BA.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2014-10-01   100.0000
# 2014-10-02    99.5990
# 2014-10-03   101.3556
# 2014-10-04        NaN
# 2014-10-05        NaN
#                ...
# 2026-02-05   218.5751
# 2026-02-06   224.1836
# 2026-02-07        NaN
# 2026-02-08        NaN
# 2026-02-09   225.7334
# Name: BA, Length: 4150, dtype: float64

# %%
close.iloc[0] # first price of all tickers
# Out:
# Ticker
# BA              108.4067
# BTC-USD         383.6150
# EURUSD=X          1.2628
# GC=F           1214.6000
# MSFT             38.8802
# RELIANCE.NS     198.4096
# ^DJI          16804.7109
# Name: 2014-10-01 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
# Ticker           BA    BTC-USD  EURUSD=X     GC=F      MSFT  RELIANCE.NS  \
# Date
# 2014-10-01 100.0000   100.0000  100.0000 100.0000  100.0000     100.0000
# 2014-10-02  99.5990    97.7730   99.9672  99.9671   99.6949          NaN
# 2014-10-03 101.3556    93.7169  100.3345  98.1558  100.4139          NaN
# 2014-10-04      NaN    85.7281       NaN      NaN       NaN          NaN
# 2014-10-05      NaN    83.5499       NaN      NaN       NaN          NaN
# ...             ...        ...       ...      ...       ...          ...
# 2026-02-05 218.5751 16345.0593   93.4536 400.2470 1012.5212     727.4851
# 2026-02-06 224.1836 18392.2402   93.2654 407.6404 1031.7340     731.2148
# 2026-02-07      NaN 18060.2871       NaN      NaN       NaN          NaN
# 2026-02-08      NaN 18316.4705       NaN      NaN       NaN          NaN
# 2026-02-09 225.7334 18278.9471   93.6448 415.8488 1063.7812     736.6580
#
# Ticker         ^DJI
# Date
# 2014-10-01 100.0000
# 2014-10-02  99.9782
# 2014-10-03 101.2198
# 2014-10-04      NaN
# 2014-10-05      NaN
# ...             ...
# 2026-02-05 291.0417
# 2026-02-06 298.2239
# 2026-02-07      NaN
# 2026-02-08      NaN
# 2026-02-09 298.3441
#
# [4150 rows x 7 columns]

# %%
norm.dropna().plot(figsize=(15,8), fontsize=13, logy = True)
plt.legend(fontsize=13)
plt.show()

# %%
## Take home: Normalized prices help to compare Financial Instruments...
# but they are limited in comparing performance in details

# %%
close.to_csv("close.csv")
