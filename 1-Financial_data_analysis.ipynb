# %%
import pandas as py
import yfinance as yf

# %%
start="2014-10-01"
end="2026-02-10"

# %%
symbol= ["BA", "MSFT", "^DJI", "EURUSD=X", "GC=F", "BTC-USD"]

# %%
yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  6 of 6 completed
# Price            Close                                                   \
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT
# Date
# 2014-10-01  108.406685    383.614990  1.262834  1214.599976   38.880161
# 2014-10-02  107.971901    375.071991  1.262419  1214.199951   38.761566
# 2014-10-03  109.876205    359.511993  1.267058  1192.199951   39.041100
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2026-02-05  236.949997  62702.097656  1.180164  4861.399902  393.670013
# 2026-02-06  243.029999  70555.390625  1.177787  4951.200195  401.140015
# 2026-02-07         NaN  69281.968750       NaN          NaN         NaN
# 2026-02-08         NaN  70264.726562       NaN          NaN         NaN
# ...

# %%
df = yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
print(df)
# Out:
# Price            Close                                                   \
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT
# Date
# 2014-10-01  108.406685    383.614990  1.262834  1214.599976   38.880161
# 2014-10-02  107.971901    375.071991  1.262419  1214.199951   38.761566
# 2014-10-03  109.876205    359.511993  1.267058  1192.199951   39.041100
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2026-02-05  236.949997  62702.097656  1.180164  4861.399902  393.670013
# 2026-02-06  243.029999  70555.390625  1.177787  4951.200195  401.140015
# 2026-02-07         NaN  69281.968750       NaN          NaN         NaN
# 2026-02-08         NaN  70264.726562       NaN          NaN         NaN
# 2026-02-09  244.710007  70120.781250  1.182578  5050.899902  413.600006
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4150 entries, 2014-10-01 to 2026-02-09
# Freq: D
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, BA)         2856 non-null   float64
#  1   (Close, BTC-USD)    4150 non-null   float64
#  2   (Close, EURUSD=X)   2956 non-null   float64
#  3   (Close, GC=F)       2855 non-null   float64
#  4   (Close, MSFT)       2856 non-null   float64
#  5   (Close, ^DJI)       2856 non-null   float64
#  6   (High, BA)          2856 non-null   float64
#  7   (High, BTC-USD)     4150 non-null   float64
#  8   (High, EURUSD=X)    2956 non-null   float64
#  9   (High, GC=F)        2855 non-null   float64
#  10  (High, MSFT)        2856 non-null   float64
#  11  (High, ^DJI)        2856 non-null   float64
#  12  (Low, BA)           2856 non-null   float64
#  13  (Low, BTC-USD)      4150 non-null   float64
# ...

# %%
df.to_csv("multi_assets.csv")

# %%
# Visualize the data
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8-whitegrid")

# %%
df = pd.read_csv("multi_assets.csv", header = [0,1], index_col=0, parse_dates=[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4150 entries, 2014-10-01 to 2026-02-09
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, BA)         2856 non-null   float64
#  1   (Close, BTC-USD)    4150 non-null   float64
#  2   (Close, EURUSD=X)   2956 non-null   float64
#  3   (Close, GC=F)       2855 non-null   float64
#  4   (Close, MSFT)       2856 non-null   float64
#  5   (Close, ^DJI)       2856 non-null   float64
#  6   (High, BA)          2856 non-null   float64
#  7   (High, BTC-USD)     4150 non-null   float64
#  8   (High, EURUSD=X)    2956 non-null   float64
#  9   (High, GC=F)        2855 non-null   float64
#  10  (High, MSFT)        2856 non-null   float64
#  11  (High, ^DJI)        2856 non-null   float64
#  12  (Low, BA)           2856 non-null   float64
#  13  (Low, BTC-USD)      4150 non-null   float64
#  14  (Low, EURUSD=X)     2956 non-null   float64
# ...

# %%
df.Volume # outer index level
# Out:
# Ticker               BA       BTC-USD  EURUSD=X      GC=F          MSFT  \
# Date
# 2014-10-01 5265200.0000      26229400    0.0000  178.0000 38088400.0000
# 2014-10-02 3204500.0000      21777700    0.0000  176.0000 25119400.0000
# 2014-10-03 3075900.0000      30901200    0.0000  499.0000 32453200.0000
# 2014-10-04          NaN      47236500       NaN       NaN           NaN
# 2014-10-05          NaN      83308096       NaN       NaN           NaN
# ...                 ...           ...       ...       ...           ...
# 2026-02-05 7377300.0000  125509410908    0.0000  793.0000 66289200.0000
# 2026-02-06 6701200.0000  114674259489    0.0000 1386.0000 53515300.0000
# 2026-02-07          NaN   62347107663       NaN       NaN           NaN
# 2026-02-08          NaN   39721722619       NaN       NaN           NaN
# 2026-02-09 4707200.0000   52081598792    0.0000  170.0000 45480500.0000
#
# Ticker               ^DJI
# Date
# 2014-10-01 104240000.0000
# 2014-10-02  75490000.0000
# ...

# %%
df.Volume.BA # one columne
# Out:
# Date
# 2014-10-01   5265200.0000
# 2014-10-02   3204500.0000
# 2014-10-03   3075900.0000
# 2014-10-04            NaN
# 2014-10-05            NaN
#                  ...
# 2026-02-05   7377300.0000
# 2026-02-06   6701200.0000
# 2026-02-07            NaN
# 2026-02-08            NaN
# 2026-02-09   4707200.0000
# Name: BA, Length: 4150, dtype: float64

# %%
df.loc[:, ("Volume", "BA")] #one column
# Out:
# Date
# 2014-10-01   5265200.0000
# 2014-10-02   3204500.0000
# 2014-10-03   3075900.0000
# 2014-10-04            NaN
# 2014-10-05            NaN
#                  ...
# 2026-02-05   7377300.0000
# 2026-02-06   6701200.0000
# 2026-02-07            NaN
# 2026-02-08            NaN
# 2026-02-09   4707200.0000
# Name: (Volume, BA), Length: 4150, dtype: float64

# %%
df.loc["2015-01-07"] # one day/row
# Out:
# Price   Ticker
# Close   BA              113.2724
#         BTC-USD         294.3370
#         EURUSD=X          1.1875
#         GC=F           1210.6000
#         MSFT             39.4067
#         ^DJI          17584.5195
# High    BA              113.6747
#         BTC-USD         298.7540
#         EURUSD=X          1.1900
#         GC=F           1219.2000
#         MSFT             39.6027
#         ^DJI          17597.0801
# Low     BA              112.5814
#         BTC-USD         283.0790
#         EURUSD=X          1.1804
#         GC=F           1210.6000
#         MSFT             38.7759
#         ^DJI          17374.7793
# Open    BA              112.5989
#         BTC-USD         286.0770
#         EURUSD=X          1.1875
#         GC=F           1219.2000
#         MSFT             39.1936
#         ^DJI          17374.7793
# Volume  BA          3573200.0000
#         BTC-USD    24866800.0000
#         EURUSD=X          0.0000
#         GC=F             29.0000
# ...

# %%
df.loc["2015"] # one year
# Out:
# Price         Close                                                    High  \
# Ticker           BA  BTC-USD EURUSD=X      GC=F    MSFT       ^DJI       BA
# Date
# 2015-01-01      NaN 314.2490   1.2099       NaN     NaN        NaN      NaN
# 2015-01-02 113.6572 315.0320   1.2089 1186.0000 39.8584 17832.9902 115.3103
# 2015-01-03      NaN 281.0820      NaN       NaN     NaN        NaN      NaN
# 2015-01-04      NaN 264.1950      NaN       NaN     NaN        NaN      NaN
# 2015-01-05 112.8701 274.4740   1.1946 1203.9000 39.4919 17501.6504 113.6310
# ...             ...      ...      ...       ...     ...        ...      ...
# 2015-12-27      NaN 422.8230      NaN       NaN     NaN        NaN      NaN
# 2015-12-28 129.6283 422.2790   1.0966 1070.5000 48.9904 17528.2695 129.7449
# 2015-12-29 132.1484 432.9830   1.0975 1077.5000 49.5158 17720.9805 132.3367
# 2015-12-30 131.3054 426.6200   1.0928 1060.1000 49.3056 17603.8691 132.7313
# ...

# %%
df.loc["2020-06":, ("Volume", "BA")] # one month for one column
# Out:
# Date
# 2020-06-01   27127300.0000
# 2020-06-02   24780500.0000
# 2020-06-03   66486400.0000
# 2020-06-04   67155600.0000
# 2020-06-05   99846000.0000
#                   ...
# 2026-02-05    7377300.0000
# 2026-02-06    6701200.0000
# 2026-02-07             NaN
# 2026-02-08             NaN
# 2026-02-09    4707200.0000
# Name: (Volume, BA), Length: 2080, dtype: float64

# %%
df = df.swaplevel(axis = "columns").sort_index(axis="columns") #swap outer and inner index
df
# Out:
# Price         Close                                                    \
# Ticker           BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 108.4067   383.6150   1.2628 1214.6000  38.8802 16804.7109
# 2014-10-02 107.9719   375.0720   1.2624 1214.2000  38.7616 16801.0508
# 2014-10-03 109.8762   359.5120   1.2671 1192.2000  39.0411 17009.6895
# 2014-10-04      NaN   328.8660      NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100      NaN       NaN      NaN        NaN
# ...             ...        ...      ...       ...      ...        ...
# 2026-02-05 236.9500 62702.0977   1.1802 4861.3999 393.6700 48908.7188
# 2026-02-06 243.0300 70555.3906   1.1778 4951.2002 401.1400 50115.6719
# 2026-02-07      NaN 69281.9688      NaN       NaN      NaN        NaN
# 2026-02-08      NaN 70264.7266      NaN       NaN      NaN        NaN
# 2026-02-09 244.7100 70120.7812   1.1826 5050.8999 413.6000 50135.8711
#
# ...

# %%
close = df.Close.copy() # select daily close price only
close
# Out:
# Ticker           BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 108.4067   383.6150    1.2628 1214.6000  38.8802 16804.7109
# 2014-10-02 107.9719   375.0720    1.2624 1214.2000  38.7616 16801.0508
# 2014-10-03 109.8762   359.5120    1.2671 1192.2000  39.0411 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2026-02-05 236.9500 62702.0977    1.1802 4861.3999 393.6700 48908.7188
# 2026-02-06 243.0300 70555.3906    1.1778 4951.2002 401.1400 50115.6719
# 2026-02-07      NaN 69281.9688       NaN       NaN      NaN        NaN
# 2026-02-08      NaN 70264.7266       NaN       NaN      NaN        NaN
# 2026-02-09 244.7100 70120.7812    1.1826 5050.8999 413.6000 50135.8711
#
# [4150 rows x 6 columns]

# %%
close.describe()
# Out:
# Ticker        BA     BTC-USD  EURUSD=X      GC=F      MSFT       ^DJI
# count  2856.0000   4150.0000 2956.0000 2855.0000 2856.0000  2856.0000
# mean    208.7822  27510.4727    1.1235 1785.9736  204.6902 29112.3640
# std      76.7452  32054.2271    0.0550  720.2865  145.1291  8732.7721
# min      95.0100    178.1030    0.9596 1050.8000   34.4372 15660.1797
# 25%     147.3250   2950.3100    1.0857 1266.2000   66.3181 21569.3203
# 50%     195.4100  11000.9878    1.1193 1692.9000  178.0707 27692.1855
# 75%     238.3125  42941.8076    1.1648 1938.9000  313.3869 34787.9316
# max     430.3000 124752.5312    1.2822 5318.3999  541.0574 50135.8711

# %%
close.BA.dropna().plot(figsize = (15,8), fontsize = 13)
plt.legend(fontsize=13)
plt.show()

# %%
close.dropna().plot(figsize = (15,8), fontsize = 13)
plt.legend(fontsize=13)
plt.show()
